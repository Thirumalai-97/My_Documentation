# %%
import os
from platform import system
import tkinter
from tkinter import LEFT, END, DISABLED, NORMAL
import warnings
import qiskit
from qiskit import QuantumCircuit
from qiskit.visualization import visualize_transition

# %%
# ignores unwanted warnings 
warnings.simplefilter("ignore")

# %%
background = '#2c94c8'
button = '#2c94c8'
special_buttons='#2c94c8'
button_font=('Arial', 18)
display_font = ('Arial', 18)

# %%
def intialize_circuit():
    global intialize_circuit
    circuit = QuantumCircuit(1)
intialize_circuit()

thete = 0 


class QuantumGates:

    def __init__(self):
        pass

    def about():

        info = tkinter.Tk()
        info.title('About')
        info.geometry('650x478')

        text = tkinter.Text(inof, height= 30, width = 30)

        #creating label 
        label = tkinter.Label(info, text = "Quantum Gates")

        label.pack()
        text.pack(fill='both', expand=True)
        text.insert(END, text_to_display)

#running
        info.mainloop()

    def change_theta(num, window, circuit, key):

        global theta
        theta = num*np.pi
        if key =='x':
            circuit.rx(theta, 0)
            theta=0
        elif key=='y':
            circuit.ry(theta, 0)
            theta=0
        else :
            circuit.rz(theta, 0)
            theta=0
    
    def user_input(self, circuit, key):

        get_input = tkinter.Tk()
        get_input.title('Get Theta')

        get_input.geometry('260x445')
        get_input.resizable(0,0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
        val1.grid(row=0,column=0)

        text_object = tkinter.Text(get_input, height = 20, width=30,bg='yellow')

        note "Give the value for theta"

        
        text_object.grid(sticky='WE', columnspan=4)
        text_object.insert(END, note)

        get_input.mainloop()
# Out:
#   Cell In[10], line 54
#     val1= tkinter.Button(get_input, height=3, width=15, bg=buttonx, font=("Arial"), text='PI/4', command=lamda:self.change_theta(0.25,get_input,circuit,key))
#                                                                                                               ^
# SyntaxError: invalid syntax
