# %%
from qiskit.quantum_info import *
from qiskit import *
import numpy as np
import math
from qiskit.quantum_info import concurrence, state_fidelity, average_gate_fidelity, process_fidelity

qc = QuantumCircuit(2)
qc.x(1)
qc.h(0)
qc.cx(0,1)
qc.draw('mpl')

# %%
rho_0 = np.real(DensityMatrix(qc).data)
rho_0
# Out:
# array([[0. , 0. , 0. , 0. ],
#        [0. , 0.5, 0.5, 0. ],
#        [0. , 0.5, 0.5, 0. ],
#        [0. , 0. , 0. , 0. ]])

# %%
state_0 = np.real(Statevector(qc).data)
state_0
# Out:
# array([0.        , 0.70710678, 0.70710678, 0.        ])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
b = 1   # Angular momentum (omega), constant value
temp_value = 0.00001 # Temperature value
gamma_0_values = [0.1, 0.2, 0.30]  # Gamma_0 values
time_values = np.linspace(0, 20, 10)  # Time values for plotting from 0 to 100 with step 1
#print(len(time_values))
# Functions
def calculate_N(temp_value):
    return 1 / (np.exp((b) / (temp_value)) - 1)

def calculate_lambda(gamma_0, t):
    result = 1 - np.exp(-gamma_0 * t)
    #print(f"Gamma_0: {gamma_0}, t: {t}, Result: {result}")
    return result


def calculate_gamma(gamma_0, N, t):
    return 1 - np.exp(-gamma_0 * (2 * N + 1) * t)

def calculate_P(N):
    return (N + 1) / (2 * N + 1)

# Calculate N for the single temperature value
N = calculate_N(temp_value)
p = calculate_P(N)

# Plotting
plt.figure(figsize=(10, 6))


# Iterate over gamma_0 values
for gamma_0 in gamma_0_values:
    # Calculate lambda and gamma for the single time value
    lambda_values = calculate_lambda(gamma_0, time_values)
    gamma_values = calculate_gamma(gamma_0, N, time_values)
    #print(f"Lambda Values: {lambda_values}")
    #print(f"Gamma Values: {gamma_values}")
    concurrence_values = []

    # Initialize list to store concurrence values for each time step

    # Iterate over time values
    for t, lambda_val, gamma_val in zip(time_values, lambda_values, gamma_values):
        #print(f"Time: {t}, Lambda: {lambda_val}, Gamma: {gamma_val}")
        # Assuming rho_0 is defined somewhere

        # Define Kraus operators for the first type
        K0 = np.array([[1, 0], [0, np.sqrt(1 - lambda_val)]])
        K1 = np.array([[0, np.sqrt(lambda_val)], [0, 0]])
        K = [K0, K1]  # List of Kraus operators K_i

        # Define Kraus operators for the second type
        E0 = np.sqrt(p) * np.array([[1, 0], [0, np.sqrt(1 - gamma_val)]])
        E1 = np.sqrt(p) * np.array([[0, np.sqrt(gamma_val)], [0, 0]])
        E2 = np.sqrt(1 - p) * np.array([[np.sqrt(1 - gamma_val), 0], [0, 1]])
        E3 = np.sqrt(1 - p) * np.array([[0, 0], [np.sqrt(gamma_val), 0]])
        E = [E0, E1, E2, E3]  # List of Kraus operators E_j

        # Initialize the result matrix rho(t) as a zero matrix of appropriate size
        rho_t = np.zeros_like(rho_0)

        # Iterate over all combinations of K and E
        for K_i in K:
            for E_j in E:
                # Calculate the Kronecker product of K_i and E_j
                kron_product = np.kron(K_i, E_j)

                # Calculate the conjugate transpose (Hermitian) of K_i and E_j
                kron_conj_transpose = np.conj(kron_product).T #np.kron(np.conj(K_i.T), np.conj(E_j.T))

                # Apply the formula: kron_product * rho_0 * kron_conj_transpose
                rho_t += np.dot(kron_product, np.dot(rho_0, kron_conj_transpose))

        # Calculate concurrence for rho_t at current time step
        con_t = concurrence(rho_t)
        concurrence_values.append(con_t)

    # Plot concurrence values for current gamma_0
    plt.plot(time_values, concurrence_values, label=f'Gamma_0 = {gamma_0}', marker='o', linestyle='-')

plt.xlabel('Time')
plt.ylabel('Concurrence')
plt.title('Concurrence vs Time for different Gamma_0 values')
plt.legend()
plt.grid(True)
plt.show()
concurrence_values
# Out:
# /var/folders/s5/3vrfy9z53w54xh40slw5vx980000gn/T/ipykernel_6741/2846702897.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (np.exp((b) / (temp_value)) - 1)
# [0.9999999999999994,
#  0.5134171190325919,
#  0.26359713811572666,
#  0.13533528323661265,
#  0.06948345122280151,
#  0.035673993347252395,
#  0.018315638888734213,
#  0.00940356255149521,
#  0.004827949993831404,
#  0.0024787521766663754]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
b = 1   # Angular momentum (omega), constant value
temp_value = 0.0001 # Temperature value

gamma_0_values = [0.1, 0.2, 0.3]  # Gamma_0 values
time_values = np.linspace(0, 20, 10)  # Time values for plotting from 0 to 100 with step 1
#print(len(time_values))
# Functions
def calculate_N(temp_value):
    return 1 / (np.exp((b) / (temp_value)) - 1)

def calculate_lambda(gamma_0, t):
    result = 1 - np.exp(-gamma_0 * t)
    #print(f"Gamma_0: {gamma_0}, t: {t}, Result: {result}")
    return result


def calculate_gamma(gamma_0, N, t):
    return 1 - np.exp(-gamma_0 * (2 * N + 1) * t)

def calculate_P(N):
    return (N + 1) / (2 * N + 1)

# Calculate N for the single temperature value
N = calculate_N(temp_value)
p = calculate_P(N)

# Plotting
plt.figure(figsize=(10, 6))


# Iterate over gamma_0 values
for gamma_0 in gamma_0_values:
    # Calculate lambda and gamma for the single time value
    lambda_values = calculate_lambda(gamma_0, time_values)
    gamma_values = calculate_gamma(gamma_0, N, time_values)
    #print(f"Lambda Values: {lambda_values}")
    #print(f"Gamma Values: {gamma_values}")
    concurrence_values = []

    # Initialize list to store concurrence values for each time step

    # Iterate over time values
    for t, lambda_val, gamma_val in zip(time_values, lambda_values, gamma_values):
        #print(f"Time: {t}, Lambda: {lambda_val}, Gamma: {gamma_val}")
        # Assuming rho_0 is defined somewhere

        # Define Kraus operators for the first type
        K0 = np.array([[1, 0], [0, np.sqrt(1 - lambda_val)]])
        K1 = np.array([[0, np.sqrt(lambda_val)], [0, 0]])
        K = [K0, K1]  # List of Kraus operators K_i

        # Define Kraus operators for the second type
        E0 = np.sqrt(p) * np.array([[1, 0], [0, np.sqrt(1 - gamma_val)]])
        E1 = np.sqrt(p) * np.array([[0, np.sqrt(gamma_val)], [0, 0]])
        E2 = np.sqrt(1 - p) * np.array([[np.sqrt(1 - gamma_val), 0], [0, 1]])
        E3 = np.sqrt(1 - p) * np.array([[0, 0], [np.sqrt(gamma_val), 0]])
        E = [E0, E1, E2, E3]  # List of Kraus operators E_j

        # Initialize the result matrix rho(t) as a zero matrix of appropriate size
        rho_t = np.zeros_like(rho_0)

        # Iterate over all combinations of K and E
        for K_i in K:
            for E_j in E:
                # Calculate the Kronecker product of K_i and E_j
                kron_product = np.kron(K_i, E_j)

                # Calculate the conjugate transpose (Hermitian) of K_i and E_j
                kron_conj_transpose = np.conj(kron_product).T #np.kron(np.conj(K_i.T), np.conj(E_j.T))

                # Apply the formula: kron_product * rho_0 * kron_conj_transpose
                rho_t += np.dot(kron_product, np.dot(rho_0, kron_conj_transpose))

        # Calculate concurrence for rho_t at current time step
        con_t = state_fidelity(rho_0, rho_t)
        concurrence_values.append(con_t)

    # Plot concurrence values for current gamma_0
    plt.plot(time_values, concurrence_values, label=f'Gamma_0 = {gamma_0}', marker='o', linestyle='-')

plt.xlabel('Time')
plt.ylabel('State Fidelity')
plt.title('State Fidelity vs Time for different Gamma_0 values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/s5/3vrfy9z53w54xh40slw5vx980000gn/T/ipykernel_6741/2658988736.py:13: RuntimeWarning: overflow encountered in exp
#   return 1 / (np.exp((b) / (temp_value)) - 1)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
b = 1   # Angular momentum (omega), constant value
gamma_0 = 0.3 # Keeping gamma_0 constant
temp_values = [0.1, 1, 10]  # Temperature values
time_values = np.linspace(0, 30, 50)  # Time values for plotting from 0 to 100 with step 1

# Functions
def calculate_N(temp_value):
    return 1 / (np.exp((b) / (temp_value)) - 1)

def calculate_lambda(gamma_0, t):
    result = 1 - np.exp(-gamma_0 * t)
    return result

def calculate_gamma(gamma_0, N, t):
    return 1 - np.exp(-gamma_0 * (2 * N + 1) * t)

def calculate_P(N):
    return (N + 1) / (2 * N + 1)

# Plotting
plt.figure(figsize=(10, 6))

# Iterate over temperature values
for temp_value in temp_values:
    # Calculate N for the current temperature value
    N = calculate_N(temp_value)
    p = calculate_P(N)

    lambda_values = calculate_lambda(gamma_0, time_values)
    gamma_values = calculate_gamma(gamma_0, N, time_values)
    concurrence_values = []

    # Iterate over time values
    for t, lambda_val, gamma_val in zip(time_values, lambda_values, gamma_values):
        # Define Kraus operators for the first type
        K0 = np.array([[1, 0], [0, np.sqrt(1 - lambda_val)]])
        K1 = np.array([[0, np.sqrt(lambda_val)], [0, 0]])
        K = [K0, K1]  # List of Kraus operators K_i

        # Define Kraus operators for the second type
        E0 = np.sqrt(p) * np.array([[1, 0], [0, np.sqrt(1 - gamma_val)]])
        E1 = np.sqrt(p) * np.array([[0, np.sqrt(gamma_val)], [0, 0]])
        E2 = np.sqrt(1 - p) * np.array([[np.sqrt(1 - gamma_val), 0], [0, 1]])
        E3 = np.sqrt(1 - p) * np.array([[0, 0], [np.sqrt(gamma_val), 0]])
        E = [E0, E1, E2, E3]  # List of Kraus operators E_j

        rho_t = np.zeros_like(rho_0)

        # Iterate over all combinations of K and E
        for K_i in K:
            for E_j in E:
                kron_product = np.kron(K_i, E_j)
                kron_conj_transpose = np.conj(kron_product).T
                rho_t += np.dot(kron_product, np.dot(rho_0, kron_conj_transpose))

        con_t = concurrence(rho_t)
        concurrence_values.append(con_t)

    # Plot concurrence values for current temperature value
    plt.plot(time_values, concurrence_values, label=f'Temp = {temp_value}', marker='o', linestyle='-')

plt.xlabel('Time')
plt.ylabel('Concurrence')
plt.title('Concurrence vs Time for different Temperature values (with constant Gamma_0)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
b = 1   # Angular momentum (omega), constant value
gamma_0 = 0.3 # Keeping gamma_0 constant
temp_values = [0.1, 1, 10]  # Temperature values
time_values = np.linspace(0, 20, 10)  # Time values for plotting from 0 to 100 with step 1

# Functions
def calculate_N(temp_value):
    return 1 / (np.exp((b) / (temp_value)) - 1)

def calculate_lambda(gamma_0, t):
    result = 1 - np.exp(-gamma_0 * t)
    return result

def calculate_gamma(gamma_0, N, t):
    return 1 - np.exp(-gamma_0 * (2 * N + 1) * t)

def calculate_P(N):
    return (N + 1) / (2 * N + 1)

# Plotting
plt.figure(figsize=(10, 6))

# Iterate over temperature values
for temp_value in temp_values:
    # Calculate N for the current temperature value
    N = calculate_N(temp_value)
    p = calculate_P(N)

    lambda_values = calculate_lambda(gamma_0, time_values)
    gamma_values = calculate_gamma(gamma_0, N, time_values)
    concurrence_values = []

    # Iterate over time values
    for t, lambda_val, gamma_val in zip(time_values, lambda_values, gamma_values):
        # Define Kraus operators for the first type
        K0 = np.array([[1, 0], [0, np.sqrt(1 - lambda_val)]])
        K1 = np.array([[0, np.sqrt(lambda_val)], [0, 0]])
        K = [K0, K1]  # List of Kraus operators K_i

        # Define Kraus operators for the second type
        E0 = np.sqrt(p) * np.array([[1, 0], [0, np.sqrt(1 - gamma_val)]])
        E1 = np.sqrt(p) * np.array([[0, np.sqrt(gamma_val)], [0, 0]])
        E2 = np.sqrt(1 - p) * np.array([[np.sqrt(1 - gamma_val), 0], [0, 1]])
        E3 = np.sqrt(1 - p) * np.array([[0, 0], [np.sqrt(gamma_val), 0]])
        E = [E0, E1, E2, E3]  # List of Kraus operators E_j

        rho_t = np.zeros_like(rho_0)

        # Iterate over all combinations of K and E
        for K_i in K:
            for E_j in E:
                kron_product = np.kron(K_i, E_j)
                kron_conj_transpose = np.conj(kron_product).T
                rho_t += np.dot(kron_product, np.dot(rho_0, kron_conj_transpose))

        con_t = state_fidelity(rho_0,rho_t)
        concurrence_values.append(con_t)

    # Plot concurrence values for current temperature value
    plt.plot(time_values, concurrence_values, label=f'Temp = {temp_value}', marker='o', linestyle='-')

plt.xlabel('Time')
plt.ylabel('State fidelity')
plt.title('State Fidelity vs Time for different Temperature values (with constant Gamma_0)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
b = 1   # Angular momentum (omega), constant value
gamma_0_values = [0.1, 0.2, 0.3, 0.4]  # Gamma_0 values
temp_values = np.linspace(0, 20, 10)  # Temperature values
time_values = 1  # Time values for plotting (constant)

# Functions
def calculate_N(temp_value):
    return 1 / (np.exp((b) / (temp_value)) - 1)

def calculate_lambda(gamma_0, t):
    result = 1 - np.exp(-gamma_0 * t)
    return result

def calculate_gamma(gamma_0, N, t):
    return 1 - np.exp(-gamma_0 * (2 * N + 1) * t)

def calculate_P(N):
    return (N + 1) / (2 * N + 1)

# Plotting
plt.figure(figsize=(10, 6))

# Iterate over gamma_0 values
for gamma_0 in gamma_0_values:
    concurrence_values = []

    # Iterate over temperature values
    for temp_value in temp_values:
        # Calculate N for the current temperature value
        N = calculate_N(temp_value)
        p = calculate_P(N)

        lambda_values = calculate_lambda(gamma_0, time_values)
        gamma_values = calculate_gamma(gamma_0, N, time_values)

        # Define Kraus operators for the first type
        K0 = np.array([[1, 0], [0, np.sqrt(1 - lambda_values)]])
        K1 = np.array([[0, np.sqrt(lambda_values)], [0, 0]])
        K = [K0, K1]  # List of Kraus operators K_i

        # Define Kraus operators for the second type
        E0 = np.sqrt(p) * np.array([[1, 0], [0, np.sqrt(1 - gamma_values)]])
        E1 = np.sqrt(p) * np.array([[0, np.sqrt(gamma_values)], [0, 0]])
        E2 = np.sqrt(1 - p) * np.array([[np.sqrt(1 - gamma_values), 0], [0, 1]])
        E3 = np.sqrt(1 - p) * np.array([[0, 0], [np.sqrt(gamma_values), 0]])
        E = [E0, E1, E2, E3]  # List of Kraus operators E_j

        rho_t = np.zeros_like(rho_0)

        # Iterate over all combinations of K and E
        for K_i in K:
            for E_j in E:
                kron_product = np.kron(K_i, E_j)
                kron_conj_transpose = np.conj(kron_product).T
                rho_t += np.dot(kron_product, np.dot(rho_0, kron_conj_transpose))

        con_t = concurrence(rho_t)
        concurrence_values.append(con_t)

    # Plot concurrence values for current gamma_0 value
    plt.plot(temp_values, concurrence_values, label=f'Gamma_0 = {gamma_0}', marker='o', linestyle='-')

plt.xlabel('Temperature')
plt.ylabel('Concurrence')
plt.title('Concurrence vs Temperature for different Gamma_0 values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/s5/3vrfy9z53w54xh40slw5vx980000gn/T/ipykernel_6741/1177201628.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / (np.exp((b) / (temp_value)) - 1)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
b = 1   # Angular momentum (omega), constant value
gamma_0_values = [0.1, 0.2, 0.3, 0.4]  # Gamma_0 values
temp_values = np.linspace(0, 30, 10)  # Temperature values
time_values = 1  # Time values for plotting (constant)

# Functions
def calculate_N(temp_value):
    return 1 / (np.exp((b) / (temp_value)) - 1)

def calculate_lambda(gamma_0, t):
    result = 1 - np.exp(-gamma_0 * t)
    return result

def calculate_gamma(gamma_0, N, t):
    return 1 - np.exp(-gamma_0 * (2 * N + 1) * t)

def calculate_P(N):
    return (N + 1) / (2 * N + 1)

# Plotting
plt.figure(figsize=(10, 6))

# Iterate over gamma_0 values
for gamma_0 in gamma_0_values:
    concurrence_values = []

    # Iterate over temperature values
    for temp_value in temp_values:
        # Calculate N for the current temperature value
        N = calculate_N(temp_value)
        p = calculate_P(N)

        lambda_values = calculate_lambda(gamma_0, time_values)
        gamma_values = calculate_gamma(gamma_0, N, time_values)

        # Define Kraus operators for the first type
        K0 = np.array([[1, 0], [0, np.sqrt(1 - lambda_values)]])
        K1 = np.array([[0, np.sqrt(lambda_values)], [0, 0]])
        K = [K0, K1]  # List of Kraus operators K_i

        # Define Kraus operators for the second type
        E0 = np.sqrt(p) * np.array([[1, 0], [0, np.sqrt(1 - gamma_values)]])
        E1 = np.sqrt(p) * np.array([[0, np.sqrt(gamma_values)], [0, 0]])
        E2 = np.sqrt(1 - p) * np.array([[np.sqrt(1 - gamma_values), 0], [0, 1]])
        E3 = np.sqrt(1 - p) * np.array([[0, 0], [np.sqrt(gamma_values), 0]])
        E = [E0, E1, E2, E3]  # List of Kraus operators E_j

        rho_t = np.zeros_like(rho_0)

        # Iterate over all combinations of K and E
        for K_i in K:
            for E_j in E:
                kron_product = np.kron(K_i, E_j)
                kron_conj_transpose = np.conj(kron_product).T
                rho_t += np.dot(kron_product, np.dot(rho_0, kron_conj_transpose))

        con_t = state_fidelity(rho_0, rho_t)
        concurrence_values.append(con_t)

    # Plot concurrence values for current gamma_0 value
    plt.plot(temp_values, concurrence_values, label=f'Gamma_0 = {gamma_0}', marker='o', linestyle='-')

plt.xlabel('Temperature')
plt.ylabel('Fidelity')
plt.title('Fidelity vs Temperature for different Gamma_0 values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/s5/3vrfy9z53w54xh40slw5vx980000gn/T/ipykernel_6741/2581113821.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / (np.exp((b) / (temp_value)) - 1)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
b = 1   # Angular momentum (omega), constant value
temp_value = 0.00001 # Temperature value
gamma_0_values = [0.02, 0.1, 0.2, 0.30]  # Gamma_0 values
time_values = np.linspace(0, 100, 50)  # Time values for plotting from 0 to 100 with step 1

def coherence(rho_t):
    # Get the off-diagonal elements of the density matrix
    off_diagonal_elements = [rho_t[i, j] for i in range(len(rho_t)) for j in range(len(rho_t)) if i != j]
    
    # Calculate the absolute sum of the off-diagonal elements
    coherence_value = np.sum(np.abs(off_diagonal_elements))
    
    return coherence_value

# Functions
def calculate_N(temp_value):
    return 1 / (np.exp((b) / (temp_value)) - 1)

def calculate_lambda(gamma_0, t):
    return 1 - np.exp(-gamma_0 * t)

def calculate_gamma(gamma_0, N, t):
    return 1 - np.exp(-gamma_0 * (2 * N + 1) * t)

def calculate_P(N):
    return (N + 1) / (2 * N + 1)

# Calculate N for the single temperature value
N = calculate_N(temp_value)
p = calculate_P(N)

# Plotting
plt.figure(figsize=(10, 6))

# Iterate over gamma_0 values
for gamma_0 in gamma_0_values:
    # Calculate lambda and gamma for the single time value
    lambda_values = calculate_lambda(gamma_0, time_values)
    gamma_values = calculate_gamma(gamma_0, N, time_values)
    coherence_values = []

    # Iterate over time values
    for t, lambda_val, gamma_val in zip(time_values, lambda_values, gamma_values):
        # Define Kraus operators for the first type
        K0 = np.array([[1, 0], [0, np.sqrt(1 - lambda_val)]])
        K1 = np.array([[0, np.sqrt(lambda_val)], [0, 0]])
        K = [K0, K1]  # List of Kraus operators K_i

        # Define Kraus operators for the second type
        E0 = np.sqrt(p) * np.array([[1, 0], [0, np.sqrt(1 - gamma_val)]])
        E1 = np.sqrt(p) * np.array([[0, np.sqrt(gamma_val)], [0, 0]])
        E2 = np.sqrt(1 - p) * np.array([[np.sqrt(1 - gamma_val), 0], [0, 1]])
        E3 = np.sqrt(1 - p) * np.array([[0, 0], [np.sqrt(gamma_val), 0]])
        E = [E0, E1, E2, E3]  # List of Kraus operators E_j

        # Initialize the result matrix rho(t) as a zero matrix of appropriate size
        rho_t = np.zeros_like(rho_0)

        # Iterate over all combinations of K and E
        for K_i in K:
            for E_j in E:
                # Calculate the Kronecker product of K_i and E_j
                kron_product = np.kron(K_i, E_j)

                # Calculate the conjugate transpose (Hermitian) of K_i and E_j
                kron_conj_transpose = np.conj(kron_product).T

                # Apply the formula: kron_product * rho_0 * kron_conj_transpose
                rho_t += np.dot(kron_product, np.dot(rho_0, kron_conj_transpose))

        # Calculate coherence for rho_t at current time step
        coherence_t = coherence(rho_t)
        coherence_values.append(coherence_t)

    # Plot coherence values for current gamma_0
    plt.plot(time_values, coherence_values, label=f'Gamma_0 = {gamma_0}', marker='o', linestyle='-')

plt.xlabel('Time')
plt.ylabel('Coherence')
plt.title('Coherence vs Time for different Gamma_0 values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/s5/3vrfy9z53w54xh40slw5vx980000gn/T/ipykernel_6741/226926307.py:21: RuntimeWarning: overflow encountered in exp
#   return 1 / (np.exp((b) / (temp_value)) - 1)
